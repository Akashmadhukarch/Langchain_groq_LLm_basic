# %%
import os
os.environ["GROQ_API_KEY"] = ""

# %%
from langchain.prompts import PromptTemplate
from langchain_groq import ChatGroq

# Initialize Groq
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.7
)

# Create Prompt Template
prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}?",
)

# Format prompt manually
formatted_prompt = prompt.format(product="eco-friendly water bottles")

# Invoke model
response = llm.invoke(formatted_prompt)

print(response.content)
# Out:
# Here are some name suggestions for a company that makes eco-friendly water bottles:
#
# 1. **EcoHydrate**: A combination of "eco" and "hydrate" that conveys the brand's focus on sustainability and drinking water.
# 2. **GreenSip**: A playful name that suggests a refreshing, eco-friendly drinking experience.
# 3. **PurePlanet**: A name that evokes a sense of purity and environmental responsibility.
# 4. **Bottlewise**: A name that implies making wise, eco-friendly choices.
# 5. **HydroEco**: A straightforward name that combines "hydro" (water) with "eco" (sustainability).
# 6. **TerraBottle**: "Terra" means earth or land, conveying a sense of connection to the planet.
# 7. **SipSustain**: A name that encourages customers to make sustainable choices while sipping.
# 8. **EcoCycle**: A name that suggests a brand that promotes recycling and reducing waste.
# 9. **CleanH20**: A simple, memorable name that combines "clean" with "water" (H2O).
# 10. **NatureNest**: A name that suggests a brand that's gentle on the environment and nurturing to the planet.
#
# When choosing a name for your company, consider the following:
#
# * Make it memorable and easy to spell
# * Ensure it's available as a web domain and social media handle
# * Verify trademark status
# * Consider brand values and messaging
# * Ensure it resonates with your target audience
#
# Remember to check for available trademarks and domain names before finalizing a name for your company.
