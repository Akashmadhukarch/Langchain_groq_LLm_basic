# %%
print("hi")
# Out:
# hi

# %%
import os
os.environ["GROQ_API_KEY"] = ""

# %%
import os
print(os.getenv("GROQ_API_KEY"))

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.7
)

response = llm.invoke("Say hello in one sentence.")
print(response.content)
# Out:
# Hello, how can I assist you today?

# %%
text =" suggest me work out plan for 1 week 1hr per day"
response = llm.invoke(text)
print(response.content)
# Out:
# Here's a 1-week workout plan, with 1 hour per day, focusing on different muscle groups and increasing intensity:
#
# **Day 1: Chest and Triceps (Monday)**
#
# 1. Warm-up (5 minutes): Light cardio, jogging or jumping jacks
# 2. Barbell Bench Press (3 sets of 8-12 reps)
# 3. Incline Dumbbell Press (3 sets of 10-15 reps)
# 4. Cable Fly (3 sets of 12-15 reps)
# 5. Tricep Pushdowns (3 sets of 10-12 reps)
# 6. Overhead Dumbbell Extension (3 sets of 12-15 reps)
# 7. Cool-down (5 minutes): Stretching
#
# **Day 2: Back and Biceps (Tuesday)**
#
# 1. Warm-up (5 minutes): Light cardio, jogging or jumping jacks
# 2. Pull-ups (3 sets of 8-12 reps) or Assisted Pull-ups
# 3. Barbell Rows (3 sets of 8-12 reps)
# 4. Lat Pulldowns (3 sets of 10-12 reps)
# 5. Dumbbell Bicep Curls (3 sets of 10-12 reps)
# 6. Hammer Curls (3 sets of 10-12 reps)
# 7. Cool-down (5 minutes): Stretching
#
# **Day 3: Legs (Wednesday)**
#
# 1. Warm-up (5 minutes): Light cardio, jogging or jumping jacks
# 2. Squats (3 sets of 8-12 reps)
# 3. Leg Press (3 sets of 10-12 reps)
# 4. Lunges (3 sets of 10-12 reps per leg)
# 5. Leg Extensions (3 sets of 12-15 reps)
# 6. Leg Curls (3 sets of 10-12 reps)
# 7. Cool-down (5 minutes): Stretching
#
# **Day 4: Shoulders and Abs (Thursday)**
#
# 1. Warm-up (5 minutes): Light cardio, jogging or jumping jacks
# 2. Shoulder Press (3 sets of 8-12 reps)
# 3. Lateral Raises (3 sets of 10-12 reps)
# 4. Rear Delt Fly (3 sets of 12-15 reps)
# 5. Hanging Leg Raises (3 sets of 10-12 reps)
# 6. Plank (3 sets of 30-60 seconds)
# 7. Cool-down (5 minutes): Stretching
#
# **Day 5: Cardio and Abs (Friday)**
#
# 1. Warm-up (5 minutes): Light cardio, jogging or jumping jacks
# 2. High-Intensity Interval Training (HIIT) (20-30 minutes)
# 3. Russian Twists (3 sets of 10-12 reps)
# 4. Bicycle Crunches (3 sets of 10-12 reps)
# 5. Leg Raises (3 sets of 10-12 reps)
# 6. Plank (3 sets of 30-60 seconds)
# 7. Cool-down (5 minutes): Stretching
#
# **Day 6: Arms (Saturday)**
#
# 1. Warm-up (5 minutes): Light cardio, jogging or jumping jacks
# 2. Bench Dips (3 sets of 8-12 reps)
# 3. Barbell Curls (3 sets of 10-12 reps)
# 4. Hammer Curls (3 sets of 10-12 reps)
# 5. Tricep Extensions (3 sets of 12-15 reps)
# 6. Cable Crossovers (3 sets of 10-12 reps)
# 7. Cool-down (5 minutes): Stretching
#
# **Day 7: Rest day or Active Recovery (Sunday)**
#
# You can do light yoga, stretching, or a leisurely walk to help with recovery.
#
# **Additional Tips:**
#
# * Start with lighter weights and gradually increase the weight as you get stronger.
# * Rest for 60-90 seconds between sets, and 120-180 seconds between exercises.
# * Stay hydrated and fuel your body with a balanced diet.
# * Listen to your body and adjust the workout plan if you need more rest or have any injuries.
#
# Remember to consult with a healthcare professional or a certified personal trainer before starting any new workout plan.
